# %% [markdown]
# data exploration
# outliers --values that lies out side the range  we  need to identify that and remove
# almost all the distribution follows a niormal distribution.
# here churn is  the catogerical variable

# %%
import numpy as np
import pandas as pd
pd.set_option("display.precision",2)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#%config InlineBackend.figure_format='retina'

# %% [markdown]
# object data type is either string or alpha nureicals

# %%
df =pd.read_csv(r"C:\Users\Robin\Desktop\Statistics\Tchurn.csv")
print(df)
print(df.shape)
print(df.columns)
print(df.info())
print(df.describe())
df.head()
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# 5       AL             118        510     391-8027                yes
# 6       MA             121        510     355-9993                 no
# 7       MO             147        415     329-9001                yes
# 8       LA             117        408     335-4719                 no
# 9       WV             141        415     330-8173                yes
# 10      IN              65        415     329-6603                 no
# 11      RI              74        415     344-9403                 no
# ...

# %%
df['churn']= df['churn'].astype('int64')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
# state                     3333 non-null object
# account length            3333 non-null int64
# area code                 3333 non-null int64
# phone number              3333 non-null object
# international plan        3333 non-null object
# voice mail plan           3333 non-null object
# number vmail messages     3333 non-null int64
# total day minutes         3333 non-null float64
# total day calls           3333 non-null int64
# total day charge          3333 non-null float64
# total eve minutes         3333 non-null float64
# total eve calls           3333 non-null int64
# total eve charge          3333 non-null float64
# total night minutes       3333 non-null float64
# total night calls         3333 non-null int64
# total night charge        3333 non-null float64
# total intl minutes        3333 non-null float64
# total intl calls          3333 non-null int64
# ...

# %%
#df.state = df.state.replace(0,np.NaN)
#df.dropna(inplace=True)

# %%
df.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df.describe(include=['object','bool'])
# Out:
#        state phone number international plan voice mail plan
# count   3333         3333               3333            3333
# unique    51         3333                  2               2
# top       WV     410-5455                 no              no
# freq     106            1               3010            2411

# %%
df['churn'].value_counts()
# Out:
# False    2850
# True      483
# Name: churn, dtype: int64

# %% [markdown]
# normalize = True, gives the percentage of people who is churning,and not churning

# %%
df['churn'].value_counts(normalize = True)
# Out:
# False    0.86
# True     0.14
# Name: churn, dtype: float64

# %%
df.sort_values(by='total day calls',ascending = False).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ca4a91540060> in <module>
# ----> 1 df.sort_values(by='total day calls',ascending = False).head()
#
# NameError: name 'df' is not defined

# %%
df['total day calls'] = df['total day calls'].replace(df[df[
    'total day calls']>140]['total day calls'],np.NaN)z
df.dropna(inplace = True)
df.shape
# Out:
#   File "<ipython-input-6-d351fe90f182>", line 2
#     'total day calls']>140]['total day calls'],np.NaN)z
#                                                       ^
# SyntaxError: invalid syntax

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-ea8415b8a3ee> in <module>
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
df.sort_values(by=['churn','total day charge'],ascending=[True,False]).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c20329bc3fb7> in <module>
# ----> 1 df.sort_values(by=['churn','total day charge'],ascending=[True,False]).head()
#
# NameError: name 'df' is not defined

# %% [markdown]
# to find the loss,since the churn =1 means those are trying to change the plan type.

# %%
df[df['churn']==1].mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-85477da4f7e7> in <module>
# ----> 1 df[df['churn']==1].mean()
#
# NameError: name 'df' is not defined

# %%
df[df['churn']==1]['total day minutes']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ac1fa5a9cd99> in <module>
# ----> 1 df[df['churn']==1]['total day minutes']
#
# NameError: name 'df' is not defined

# %%
df[(df['churn']==0) & (df['international plan']=='no')]['total intl minutes'].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-302952aa71ee> in <module>
# ----> 1 df[(df['churn']==0) & (df['international plan']=='no')]['total intl minutes'].max()
#
# NameError: name 'df' is not defined

# %%
df.loc[0:5,'state':'area code']
# Out:
#   state  account length  area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415
# 5    AL             118        510

# %%
df.iloc[0:5,0:3]
# Out:
#   state  account length  area code
# 0    KS             128        415
# 1    OH             107        415
# 2    NJ             137        415
# 3    OH              84        408
# 4    OK              75        415

# %% [markdown]
# WY is the ascii value

# %%
df.apply(np.max)
# Out:
# state                           WY
# account length                 243
# area code                      510
# phone number              422-9964
# international plan             yes
# voice mail plan                yes
# number vmail messages           51
# total day minutes          3.5e+02
# total day calls            1.4e+02
# total day charge                60
# total eve minutes          3.6e+02
# total eve calls                170
# total eve charge                31
# total night minutes          4e+02
# total night calls              175
# total night charge              18
# total intl minutes              20
# total intl calls                20
# total intl charge              5.4
# customer service calls           9
# churn                         True
# dtype: object

# %%
d={'no':False,'yes':True}
df['international plan'] = df['international plan'].map(d)
df.head()
# Out:
#   state  account length  area code phone number  international plan  \
# 0    KS             128        415     382-4657               False
# 1    OH             107        415     371-7191               False
# 2    NJ             137        415     358-1921               False
# 3    OH              84        408     375-9999                True
# 4    OK              75        415     330-6626                True
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1            110.0
# 1             yes                     26              161.6            123.0
# 2              no                      0              243.4            114.0
# 3              no                      0              299.4             71.0
# 4              no                      0              166.7            113.0
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
df =df.replace({'voice mail plan':d})
df.head()
# Out:
#   state  account length  area code phone number  international plan  \
# 0    KS             128        415     382-4657               False
# 1    OH             107        415     371-7191               False
# 2    NJ             137        415     358-1921               False
# 3    OH              84        408     375-9999                True
# 4    OK              75        415     330-6626                True
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             True                     25              265.1            110.0
# 1             True                     26              161.6            123.0
# 2            False                      0              243.4            114.0
# 3            False                      0              299.4             71.0
# 4            False                      0              166.7            113.0
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# SUMMARISING THE DATA

# %%
columns_to_show = ['total day minutes','total eve minutes','total night minutes']
df.groupby(['churn'])[columns_to_show].describe(percentiles = [])
# Out:
#       total day minutes                                   total eve minutes  \
#                   count    mean    std  min    50%    max             count
# churn
# False            2850.0  175.18  50.18  0.0  177.2  315.6            2850.0
# True              483.0  206.91  69.00  0.0  217.6  350.8             483.0
#
#                                          total night minutes                 \
#          mean    std   min    50%    max               count    mean    std
# churn
# False  199.04  50.29   0.0  199.6  361.8              2850.0  200.13  51.11
# True   212.41  51.73  70.9  211.3  363.7               483.0  205.23  47.13
#
#
#         min     50%    max
# churn
# False  23.2  200.25  395.0
# True   47.4  204.80  354.9

# %%
pd.crosstab(df['churn'],df['international plan'])
# Out:
# international plan    no  yes
# churn
# False               2664  186
# True                 346  137

# %% [markdown]
# to show the result in the percentage give the normalize = TRue

# %%
pd.crosstab(df['churn'],df['voice mail plan'],normalize = True)
# Out:
# voice mail plan    no   yes
# churn
# False            0.60  0.25
# True             0.12  0.02

# %%
df.pivot_table(['total day calls','total eve calls','total night calls'],['area code'],aggfunc = 'mean')
# Out:
#            total day calls  total eve calls  total night calls
# area code
# 408                 100.50            99.79              99.04
# 415                 100.58           100.50             100.40
# 510                 100.10            99.67             100.60
