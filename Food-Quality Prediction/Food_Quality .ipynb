# %% [markdown]
# # Food-Quality Measuring System

# %% [markdown]
# Importing the wanted modules
# *** Import pandas, numpy, matplotlib,and seaborn. Then set %matplotlib inline ***

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fd474852-8aea-4a6b-9378-799a1f7809cd" name="files[]" multiple disabled />
#      <output id="result-fd474852-8aea-4a6b-9378-799a1f7809cd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving vegetable-entry.csv to vegetable-entry (2).csv

# %%
import io

VegData = pd.read_csv(io.StringIO(uploaded['vegetable-entry.csv'].decode('utf-8')))

# %%
VegData
# Out:
#             ITEM  PRESERVING TEMPERATURE  ...  ENVIRONMENT FRIENDLINESS  QUALITY
# 0     vegetable1                      32  ...                      0.98     0.89
# 1     vegetable2                      34  ...                      0.90     0.85
# 2     vegetable3                      42  ...                      0.89     0.88
# 3     vegetable4                      24  ...                      0.80     0.70
# 4     vegetable5                      26  ...                      0.92     0.90
# ..           ...                     ...  ...                       ...      ...
# 95   vegetable96                       3  ...                      0.91     0.80
# 96   vegetable97                      60  ...                      0.88     0.82
# 97   vegetable98                      55  ...                      0.87     0.87
# 98   vegetable99                      31  ...                      0.87     0.85
# 99  vegetable100                       2  ...                      0.88     0.88
#
# ...

# %% [markdown]
# The describe() function will displays the statistics information of the input data

# %%
VegData.describe()
# Out:
#        PRESERVING TEMPERATURE  ...     QUALITY
# count              100.000000  ...  100.000000
# mean                29.210000  ...    0.777800
# std                 12.120019  ...    0.151541
# min                  0.000000  ...    0.300000
# 25%                 22.000000  ...    0.700000
# 50%                 30.500000  ...    0.815000
# 75%                 34.250000  ...    0.882500
# max                 60.000000  ...    0.990000
#
# [8 rows x 12 columns]

# %%
VegData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
# ITEM                        100 non-null object
# PRESERVING TEMPERATURE      100 non-null int64
# PRESSURE (Kpa)              100 non-null float64
# HUMIDITY(%)                 100 non-null float64
# PACKING EFFICIENCY          100 non-null int64
# TRANSPORTATION TIME(Hrs)    100 non-null int64
# WATER CONTENT(%)            100 non-null float64
# TOTAL  LABOUR COST(Rs)      100 non-null int64
# PRESERVATIVES USED          100 non-null float64
# COLOUR                      100 non-null int64
# APPEARANCE                  100 non-null int64
# ENVIRONMENT FRIENDLINESS    100 non-null float64
# QUALITY                     100 non-null float64
# dtypes: float64(6), int64(6), object(1)
# memory usage: 10.3+ KB

# %%
sns.pairplot(VegData)

# %%
sns.heatmap(VegData.corr())

# %%
VegData.columns
# Out:
# Index(['ITEM', 'PRESERVING TEMPERATURE', 'PRESSURE (Kpa)', 'HUMIDITY(%)',
#        'PACKING EFFICIENCY', 'TRANSPORTATION TIME(Hrs)', 'WATER CONTENT(%)',
#        'TOTAL  LABOUR COST(Rs)', 'PRESERVATIVES USED', 'COLOUR', 'APPEARANCE',
#        'ENVIRONMENT FRIENDLINESS', 'QUALITY'],
#       dtype='object')

# %%
X = VegData[['PRESERVING TEMPERATURE', 'PRESSURE (Kpa)', 'HUMIDITY(%)',
       'PACKING EFFICIENCY', 'TRANSPORTATION TIME(Hrs)', 'WATER CONTENT(%)',
       'TOTAL  LABOUR COST(Rs)', 'PRESERVATIVES USED', 'COLOUR', 'APPEARANCE',
       'ENVIRONMENT FRIENDLINESS']]

# %%
Y = VegData[ 'QUALITY']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.4,random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lg=LinearRegression()
lg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_train
# Out:
#     PRESERVING TEMPERATURE  ...  ENVIRONMENT FRIENDLINESS
# 35                      22  ...                      0.91
# 74                      52  ...                      0.82
# 69                      37  ...                      0.90
# 24                      24  ...                      0.86
# 79                      31  ...                      0.83
# 33                      43  ...                      0.87
# 53                      22  ...                      0.83
# 98                      31  ...                      0.87
# 17                      31  ...                      0.87
# 83                      23  ...                      0.83
# 42                      13  ...                      0.86
# 93                      33  ...                      0.83
# 76                      22  ...                      0.87
# 15                      10  ...                      0.87
# 96                      60  ...                      0.88
# ...

# %%
y_train
# Out:
# 35    0.93
# 74    0.75
# 69    0.99
# 24    0.86
# 79    0.63
# 33    0.55
# 53    0.71
# 98    0.85
# 17    0.81
# 83    0.80
# 42    0.95
# 93    0.88
# 76    0.74
# 15    0.87
# 96    0.82
# 66    0.78
# 55    0.47
# 18    0.85
# 85    0.77
# 92    0.82
# 46    0.69
# 38    0.92
# 39    0.91
# 56    0.71
# 52    0.96
# 73    0.73
# 7     0.91
# 88    0.86
# 28    0.40
# 36    0.93
# 62    0.95
# 80    0.62
# 0     0.89
# 10    0.95
# 19    0.83
# 72    0.75
# 44    0.65
# 34    0.50
# 59    0.82
# 29    0.30
# 8     0.97
# 49    0.95
# 94    0.70
# 12    0.65
# 5     0.45
# 64    0.70
# 60    0.83
# 90    0.71
# 99    0.88
# 4     0.90
# 40    0.97
# 77    0.73
# 9     0.50
# 75    0.71
# 87    0.88
# 63    0.72
# 70    0.98
# 81    0.87
# 11    0.40
# 95    0.80
# Name: QUALITY, dtype: float64

# %%
lg.predict(X_test)
# Out:
# array([0.88983614, 0.92360323, 0.88130799, 0.63774478, 0.79696978,
#        0.86599994, 0.7938359 , 0.96581354, 0.73542828, 0.87419702,
#        0.93223575, 0.77438661, 0.67250518, 0.69399785, 0.95830848,
#        0.71021976, 0.96620298, 0.70590007, 0.61331499, 0.9484251 ,
#        0.53443099, 0.94044576, 0.69788229, 0.69047626, 0.91039371,
#        0.84842667, 0.63627882, 0.80936715, 0.65716626, 0.8610236 ,
#        0.81815456, 0.8923625 , 0.80311143, 0.69085727, 0.9019334 ,
#        0.7812814 , 0.58132811, 0.91428339, 0.77330495, 0.69099236])

# %%
X_test
# Out:
#     PRESERVING TEMPERATURE(Celsius)  ...  ENVIRONMENT FRIENDLINESS(%)
# 16                               39  ...                         0.88
# 1                                34  ...                         0.90
# 43                               17  ...                         0.85
# 67                               39  ...                         0.76
# 89                               29  ...                         0.81
# 21                               35  ...                         0.87
# 97                               55  ...                         0.87
# 51                               30  ...                         0.88
# 6                                25  ...                         0.82
# 41                               11  ...                         0.87
# 82                               16  ...                         0.87
# 25                               46  ...                         0.82
# ...

# %%
y_test
# Out:
# 16    0.82
# 1     0.85
# 43    0.95
# 67    0.73
# 89    0.67
# 21    0.86
# 97    0.87
# 51    0.97
# 6     0.55
# 41    0.90
# 82    0.87
# 25    0.62
# 45    0.69
# 68    0.70
# 37    0.90
# 31    0.71
# 50    0.97
# 32    0.64
# 3     0.70
# 48    0.96
# 61    0.47
# 47    0.96
# 54    0.68
# 57    0.77
# 2     0.88
# 13    0.81
# 78    0.66
# 58    0.81
# 84    0.69
# 91    0.90
# 86    0.83
# 14    0.83
# 23    0.85
# 26    0.60
# 22    0.87
# 71    0.97
# 27    0.50
# 20    0.88
# 65    0.76
# 30    0.72
# Name: QUALITY(%), dtype: float64

# %%
print(lg.intercept_)
print(lg.coef_)
# Out:
# 0.04314616963040718
# [-1.23219604e-05 -7.80615336e-04  3.13820443e-02  2.56024751e-02
#  -6.07958629e-04  4.42962102e-01 -3.22529464e-05 -6.09775641e-01
#  -3.20120655e-02 -2.02039150e-02  5.13401710e-01]

# %%
predictions= lg.predict(X_test)
predictions
# Out:
# array([0.88983614, 0.92360323, 0.88130799, 0.63774478, 0.79696978,
#        0.86599994, 0.7938359 , 0.96581354, 0.73542828, 0.87419702,
#        0.93223575, 0.77438661, 0.67250518, 0.69399785, 0.95830848,
#        0.71021976, 0.96620298, 0.70590007, 0.61331499, 0.9484251 ,
#        0.53443099, 0.94044576, 0.69788229, 0.69047626, 0.91039371,
#        0.84842667, 0.63627882, 0.80936715, 0.65716626, 0.8610236 ,
#        0.81815456, 0.8923625 , 0.80311143, 0.69085727, 0.9019334 ,
#        0.7812814 , 0.58132811, 0.91428339, 0.77330495, 0.69099236])

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,predictions)

# %%
y_test
sns.distplot((y_test-predictions),bins=50)

# %%
from sklearn import metrics
print('MAE:',metrics.mean_absolute_error(y_test,predictions))
print('MSE:',metrics.mean_squared_error(y_test,predictions))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test,predictions)))
# Out:
# MAE: 0.05331121014386299
# MSE: 0.005016729184814257
# RMSE: 0.07082887253665879
